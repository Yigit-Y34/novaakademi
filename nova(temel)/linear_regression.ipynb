# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
veriSeti = pd.read_csv("https://raw.githubusercontent.com/selva86/datasets/master/BostonHousing.csv")
veriSeti
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
x = veriSeti[["rm"]]
x
# Out:
#         rm
# 0    6.575
# 1    6.421
# 2    7.185
# 3    6.998
# 4    7.147
# ..     ...
# 501  6.593
# 502  6.120
# 503  6.976
# 504  6.794
# 505  6.030
#
# [506 rows x 1 columns]

# %%
y = veriSeti[["medv"]]
y
# Out:
#      medv
# 0    24.0
# 1    21.6
# 2    34.7
# 3    33.4
# 4    36.2
# ..    ...
# 501  22.4
# 502  20.6
# 503  23.9
# 504  22.0
# 505  11.9
#
# [506 rows x 1 columns]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = 42)

x_test
# Out:
#         rm
# 173  6.416
# 274  6.758
# 491  5.983
# 72   6.065
# 452  6.297
# ..     ...
# 412  4.628
# 436  6.461
# 411  6.657
# 86   6.015
# 75   6.286
#
# [102 rows x 1 columns]

# %%
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_test)

# %%
y_pred
# Out:
# array([[23.73238293],
#        [26.92950201],
#        [19.68456842],
#        [20.45112913],
#        [22.61993506],
#        [22.45166563],
#        [19.03953562],
#        [21.47009399],
#        [21.98425056],
#        [20.09589368],
#        [19.38542277],
#        [19.88088275],
#        [ 5.99865516],
#        [22.01229547],
#        [17.11378553],
#        [29.00482492],
#        [18.71234507],
#        [ 9.37339197],
#        [37.37155468],
#        [21.5729253 ],
#        [22.08708188],
#        [24.34937082],
#        [17.16052704],
#        [25.38703227],
#        [19.89957935],
#        [14.48691283],
#        [18.66560356],
#        [26.64905296],
#        [19.46955748],
#        [17.91773945],
#        [15.84241654],
#        [23.82586594],
#        [32.11780929],
#        [13.87927324],
#        [19.87153445],
#        [17.12313383],
#        [30.92122671],
#        [18.61886206],
#        [20.44178083],
#        [22.13382339],
#        [14.14102568],
# ...

# %%
plt.scatter(x_test,y_test,color = 'b')
plt.plot(x_test,y_pred,color = 'r')

plt.show()

# %%
VeriSeti = pd.read_csv("deneyim-maas.csv",sep = ";")

# %%
VeriSeti
# Out:
#     deneyim   maas
# 0         0   3000
# 1        10  15000
# 2         3   5000
# 3         5   7000
# 4         7  11000
# 5        12  18000
# 6         1   4000
# 7         1   3500
# 8         4   6000
# 9         4   6000
# 10        2   4500
# 11        6   9000
# 12       11  17500
# 13       15  20000
# 14       13  19000
# 15       14  19000
# 16       18  21000
# 17        5   7500
# 18        8  13000
# 19        9  13500
# 20       13  19000

# %%
x = VeriSeti[["deneyim"]]
y = VeriSeti[["maas"]]
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = 42)

x_test
# Out:
#     deneyim
# 0         0
# 17        5
# 15       14
# 1        10
# 8         4

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_test)

# %%
plt.scatter(x_test,y_test,color = 'b')
plt.plot(x_test,y_pred,color = 'r')

plt.show()

# %%
data = pd.read_csv("50_Startups.csv")
Y = data[["Profit"]]
X = data.iloc[:,0:4]
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size = 0.2,random_state = 42)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

ct = ColumnTransformer(transformers = [("encoder",OneHotEncoder(),[3])],remainder = "passthrough")

# %%
ct
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('encoder', OneHotEncoder(), [3])])

# %%
X = np.array(ct.fit_transform(X))

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size = 0.2,random_state = 1)

regressor = LinearRegression()
regressor.fit(X_train,Y_train)

y_predict = regressor.predict(X_test)

print(y_predict)
print("*****************")
print(y_test)

plt.plot(y_test)
plt.scatter(range(len(y_predict)),y_predict,color='r')
plt.show()
# Out:
# [[114664.41715867]
#  [ 90593.1553162 ]
#  [ 75692.84151574]
#  [ 70221.88679651]
#  [179790.25514874]
#  [171576.92018521]
#  [ 49753.58752029]
#  [102276.65888936]
#  [ 58649.37795761]
#  [ 98272.02561131]]
# *****************
#        Profit
# 27  105008.31
# 35   96479.51
# 40   78239.91
# 38   81229.06
# 2   191050.39
# 3   182901.99
# 48   35673.41
# 29  101004.64
# 46   49490.75
# 31   97483.56

# %%
data ={
    'Bölge': ['A','B','A','B','C','A','C','B','A','C'],
    'Oda': [3,2,3,4,3,3,4,3,2,4],
    'Metrekare':[120,85,90,110,95,100,105,80,70,130],
    'Fiyat':[300000,200000,250000,350000,270000,290000,320000,180000,150000,400000]
}

dataset = pd.Dataframe(data)

X = dataset.iloc[:,:-1].values
y = dataset.iloc[:,-1].values

from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
